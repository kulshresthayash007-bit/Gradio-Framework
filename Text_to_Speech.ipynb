# %%
# %pip install gTTS
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS

language = "en"
text = "hello world, i am a model that generates speech from text!"

# Note the capital S in gTTS here as well
speech = gTTS(text=text, lang=language, slow=False, tld="com.au")
speech.save("texttospeech.mp3")

# %%
from IPython.display import Audio 
Audio("texttospeech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio

language = "fr"
text = "hello world, i am a model that generates speech from text!"

# FIX: Change 'com.fr' to 'fr'
speech = gTTS(text=text, lang=language, slow=False, tld="fr")
speech.save("texttospeech.mp3")

# Play it directly in your notebook
Audio("texttospeech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
demo.launch(share=True)   if true then launch the
# Out:
#   Cell In[5], line 1
#     demo.launch(share=True)   if true then launch the
#     ^
# SyntaxError: expected 'else' after 'if' expression
